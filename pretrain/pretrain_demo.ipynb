# %%
import skyer_llm

skyer_llm.Trainer(data_file="../dataset/token/2021-43_zh_head_0001",
                  ss=1,
                  seq_len=512,
                  num_layers=2,
                  input_dim=256,
                  hide_dim=192,
                  n_q_heads=2,
                  n_kv_heads=1,
                  max_len=1-24,
                  num_vocs=30000)
# Out:
# [2024-10-04 08:49:50,274] [INFO] [comm.py:652:init_distributed] cdb=None
# [2024-10-04 08:49:50,277] [INFO] [comm.py:667:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# [2024-10-04 08:49:50,497] [INFO] [comm.py:717:mpi_discovery] Discovered MPI settings of world_rank=0, local_rank=0, world_size=1, master_addr=172.20.36.2, master_port=29500
# [2024-10-04 08:49:50,498] [INFO] [comm.py:683:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 3
#       1 import skyer_llm
# ----> 3 skyer_llm.Trainer(data_file="../dataset/token/2021-43_zh_head_0001",
#       4                   ss=1,
#       5                   seq_len=512,
#       6                   num_layers=2,
#       7                   input_dim=256,
# ...
